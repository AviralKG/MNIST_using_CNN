# %% [markdown]
# <a href="https://colab.research.google.com/github/AviralKG/MNIST_using_CNN/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras.datasets import mnist
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train_normalized = tf.keras.utils.normalize(x_train, axis=1)
x_test_normalized = tf.keras.utils.normalize(x_test, axis=1)
print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i],cmap='gray')
    plt.xlabel(y_train[i])
plt.show()

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(784,activation='relu'))
model.add(tf.keras.layers.Dense(900,activation='relu'))
model.add(tf.keras.layers.Dense(98,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 6000/6000 [==============================] - 21s 3ms/step - loss: 0.7463 - accuracy: 0.8587
# Epoch 2/10
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.2758 - accuracy: 0.9356
# Epoch 3/10
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.2168 - accuracy: 0.9512
# Epoch 4/10
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.2122 - accuracy: 0.9543
# Epoch 5/10
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.1996 - accuracy: 0.9586
# Epoch 6/10
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.1828 - accuracy: 0.9601
# Epoch 7/10
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.1992 - accuracy: 0.9610
# Epoch 8/10
# 6000/6000 [==============================] - 19s 3ms/step - loss: 0.2097 - accuracy: 0.9618
# Epoch 9/10
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.1645 - accuracy: 0.9664
# Epoch 10/10
# ...

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
predictions[1]
# Out:
# array([0.0000000e+00, 7.5317413e-16, 9.9999988e-01, 1.4970788e-13,
#        0.0000000e+00, 2.1948660e-38, 0.0000000e+00, 1.5760203e-07,
#        1.3431554e-21, 6.3507274e-27], dtype=float32)

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_test[i].reshape(28,28),cmap='gray')
  plt.xlabel(np.argmax(predictions[i]))
plt.show()

# %%
np.argmax(predictions[1])
# Out:
# 2

# %%
predictions[1]
# Out:
# array([0.0000000e+00, 7.5317413e-16, 9.9999988e-01, 1.4970788e-13,
#        0.0000000e+00, 2.1948660e-38, 0.0000000e+00, 1.5760203e-07,
#        1.3431554e-21, 6.3507274e-27], dtype=float32)

# %%
loss,accu = model.evaluate(x_train,y_train)
loss, accu
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2322 - accuracy: 0.9510
# (0.2321767807006836, 0.950950026512146)
